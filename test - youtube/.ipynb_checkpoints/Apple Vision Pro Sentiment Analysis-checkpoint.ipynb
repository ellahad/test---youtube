# %% [markdown]
# ## Scraping Data From Marque's Brownlee's Channel

# %%
from googleapiclient.discovery import build
import pandas as pd
import datetime

# Set up YouTube Data API
api_key = 'AIzaSyCMPe6VHU5XCIwTWN126pY4d4MrgMDoIAQ'
channelId='UCBJycsmduvYEL83R_U4JriQ'
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Function to Get Channel Statistics

# %%
def get_channel_stats(youtube,channelId):
  request = youtube.channels().list(
              part='snippet,contentDetails,statistics',
              id=channelId)
  response=request.execute()

  data = dict(Channel_name = response['items'][0]['snippet']['title'],
              Subscribers = response['items'][0]['statistics']['subscriberCount'],
              Total_videos = response['items'][0]['statistics']['videoCount'],
              Views = response['items'][0]['statistics']['viewCount'],)

  return data

# %%
get_channel_stats(youtube,channelId)
# Out:
# {'Channel_name': 'Marques Brownlee',
#  'Subscribers': '18700000',
#  'Total_videos': '878',
#  'Views': '4182199532'}

# %%
# Scraping the Channel for the 1 year Statistics
from googleapiclient.discovery import build
import pandas as pd
import datetime

# Setting up YouTube Data API
api_key = 'AIzaSyCMPe6VHU5XCIwTWN126pY4d4MrgMDoIAQ'
youtube = build('youtube', 'v3', developerKey=api_key)

# Function to fetch video details by video ID
def fetch_video_details(video_id):
    response = youtube.videos().list(
        part='snippet,statistics',
        id=video_id
    ).execute()
    return response['items'][0] if response['items'] else None

# Function to fetch videos uploaded by Marques Brownlee in the past 1 year
def fetch_videos():
    one_year_ago = (datetime.datetime.now() - datetime.timedelta(days=365)).strftime('%Y-%m-%dT%H:%M:%SZ')
    videos = []
    next_page_token = None
    while True:
        response = youtube.search().list(
            part='snippet',
            channelId='UCBJycsmduvYEL83R_U4JriQ',  # Marques Brownlee's channel ID
            maxResults=50,
            type='video',
            publishedAfter=one_year_ago,
            pageToken=next_page_token
        ).execute()
        video_ids = [item['id']['videoId'] for item in response['items']]
        for video_id in video_ids:
            video_details = fetch_video_details(video_id)
            if video_details:
                videos.append(video_details)
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break
    return videos

# Fetch videos
videos = fetch_videos()

# Extract relevant statistics for each video
video_data = []
for video in videos:
    video_info = {
        'video_title': video['snippet']['title'],
        'publishedAt': video['snippet']['publishedAt']
    }
    statistics = video.get('statistics', {})
    video_info['views'] = int(statistics.get('viewCount', 0))
    video_info['likes'] = int(statistics.get('likeCount', 0))
    video_info['comments_count'] = int(statistics.get('commentCount', 0))
    video_data.append(video_info)

# Convert to DataFrame
df = pd.DataFrame(video_data)

# Display descriptive statistics
df.describe()
# Out:
#               views         likes  comments_count
# count  1.070000e+02  1.070000e+02      107.000000
# mean   5.166240e+06  1.922625e+05     7606.598131
# std    4.829628e+06  1.906944e+05     7324.318434
# min    7.781760e+05  3.688800e+04      657.000000
# 25%    2.865587e+06  9.646250e+04     3348.000000
# 50%    3.701658e+06  1.313920e+05     5386.000000
# 75%    5.432331e+06  2.192045e+05     8725.000000
# max    3.433036e+07  1.694793e+06    41311.000000

# %%
# Checking first 5 rows
df.head()
# Out:
#                           video_title           publishedAt    views   likes  \
# 0         NEW Boston Dynamics Robot 🫣  2024-04-17T15:11:47Z  1552235   86216
# 1                        Apple Math 🍎  2023-11-06T16:32:11Z  5401739  293937
# 2                  Introducing 251.1!  2023-11-09T17:24:25Z  1061583   59424
# 3    iPhone Gets RCS! With a Catch...  2023-11-16T23:21:05Z  1059805   57606
# 4  iOS 17's "Personal Voice" Feature!  2023-07-12T18:52:40Z  2550888  118511
#
#    comments_count
# 0            3307
# 1            3703
# 2            1229
# 3            1063
# 4            1634

# %%
#Getting the Top 10 Videos by view count
import seaborn as sns
import matplotlib.pyplot as plt

# Order the videos based on views from highest to lowest
df_sorted = df.sort_values(by='views', ascending=False)

# Display the top 10 videos
top_10_videos = df_sorted.head(10)
print("Top 10 Videos:")
top_10_videos
# Out:
# Top 10 Videos:
#                                            video_title           publishedAt  \
# 12          The World's Largest iPhone Has a Secret...  2023-06-22T04:03:29Z
# 93    Using Apple Vision Pro: What It’s Actually Like!  2024-01-31T14:52:28Z
# 98   Driving Tesla Cybertruck: Everything You Need ...  2023-12-01T11:00:32Z
# 103                      Apple Vision Pro Impressions!  2023-06-06T06:39:07Z
# 6               This Airless Basketball is 3D Printed!  2024-02-19T18:23:36Z
# 85       iPhone 15/15 Pro Impressions: Not Just USB-C!  2023-09-13T05:39:41Z
# 88           Tesla Solar Roof Review: Was it Worth It?  2023-07-29T00:56:53Z
# 11              The Most Tech I've Ever Seen in a Car!  2023-05-19T17:59:11Z
# 15                Electric Scooter INSIDE a Briefcase!  2023-11-20T14:27:19Z
# 73   iPhone 15 Pro Review: The Good, The Bad, & The...  2023-09-28T22:01:44Z
#
#         views    likes  comments_count
# 12   34330359  1694793            6286
# 93   26372470   561070           32830
# 98   20873130   441176           41311
# 103  18088800   537470           39891
# 6    14551586   682840            9732
# 85   14031272   361297           25856
# 88   11230918   384786           24523
# 11   10517916   546501            5971
# 15    9151468   418879            5659
# 73    9088338   241472           17821

# %%
# Visualize the top 10 videos on a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='views', y='video_title', data=top_10_videos, palette='viridis')
plt.xlabel('Views')
plt.ylabel('Video Title')
plt.title('Top 10 Videos by Views')
plt.show()
# Out:
# <ipython-input-13-6d471a51c47c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='views', y='video_title', data=top_10_videos, palette='viridis')

# %% [markdown]
# Function to fetch comments from Apple Pro Vision Videos

# %%
# Fetching Comments from selected videos
def fetch_comments(video_id):
    comments = []
    next_page_token = None
    while True:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            maxResults=50,
            pageToken=next_page_token
        ).execute()
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append({
                'comment_text': comment['textDisplay'],
                'author': comment['authorDisplayName'],
                'likes': comment['likeCount'],
                'timestamp': comment['publishedAt']
            })
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break
    return comments

# %% [markdown]
# Fetching comments from the videos

# %%
# Video IDs
video_ids = ['dtp6b76pMak', 'OFvXuyITwBI']

# Fetch comments for each video
all_comments = []
for video_id in video_ids:
    video_comments = fetch_comments(video_id)
    all_comments.extend(video_comments)

# %%
# Display the extracted comments
for comment in all_comments:
    print(comment)

# %% [markdown]
# Storing comments in a DataFrame

# %%
import pandas as pd
comments_df = pd.DataFrame(all_comments)
comments_df.head()
# Out:
#                                         comment_text           author  likes  \
# 0                  The cable is definitely removable    @matrixmodexp      0
# 1  <a href="https://www.youtube.com/watch?v=dtp6b...       @saintpiff      0
# 2  This is a sad video of how they are Fixing to ...  @davidhelton497      0
# 3  BASE ON MY EXPERIENCE IT WILL BE PHASE-OUT IN ...        @aeoh2000      0
# 4  Typing is probably not great on this thing. Ho...     @immortalsun      0
#
#               timestamp
# 0  2024-04-21T23:33:23Z
# 1  2024-04-21T18:37:16Z
# 2  2024-04-21T15:03:32Z
# 3  2024-04-21T08:28:44Z
# 4  2024-04-21T07:28:13Z

# %%
# Saving the DataFrame as a CSV file
comments_df.to_csv('comments.csv', index=False)

# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
import string
import nltk

# %% [markdown]
# ## 1. Data Understanding:

# %%
# Checking the datatypes
comments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59253 entries, 0 to 59252
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   comment_text  59253 non-null  object
#  1   author        59253 non-null  object
#  2   likes         59253 non-null  int64
#  3   timestamp     59253 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.8+ MB

# %%
# Checking for rows with null values
comments_df.isna().sum()
# Out:
# comment_text    0
# author          0
# likes           0
# timestamp       0
# dtype: int64

# %%
# Checking for duplicates in the comment's column
print("Number of duplicated comments:", comments_df.duplicated(subset=['comment_text']).sum())
# Out:
# Number of duplicated comments: 1247

# %%
#Rows that are exact duplicates
comments_df.duplicated().sum()
# Out:
# 4

# %%
# Inspecting the duplicates
duplicates = comments_df.duplicated(subset=['comment_text'], keep=False)

# Filter to show only duplicates
duplicate_comments = comments_df[duplicates]

# Sort by 'comment_text' to better visualize duplicates next to each other
sorted_duplicate_comments = duplicate_comments.sort_values(by='comment_text')

# Display the sorted duplicates
sorted_duplicate_comments.sample(10)
# Out:
#                     comment_text                     author  likes  \
# 58823                      early                @synocle671      0
# 38439                 No thanks.              @sfentona3018      0
# 32755          ALL HAIL PLANKTON                  @hanz1491      0
# 11264                      great  @xuanthutrancongtuyet4127      0
# 48358           Ready Player One            @ericpowell4350      0
# 59033               Let&#39;s go              @ThillosDrive      0
# 38225  Comment for the algorithm                @TheTimosey      0
# 26693                       Nice                @s.spectrum      0
# 28095                       cool               @goldenchlen      0
# 39115                       Nice        @jonathanbelman8971      0
#
#                   timestamp
# 58823  2023-06-06T06:40:16Z
# 38439  2023-06-07T02:02:35Z
# 32755  2023-06-09T12:30:04Z
# 11264  2024-02-02T12:36:24Z
# 48358  2023-06-06T12:59:01Z
# 59033  2023-06-06T06:39:48Z
# 38225  2023-06-07T02:31:30Z
# 26693  2024-01-31T15:08:36Z
# 28095  2023-09-07T15:46:40Z
# 39115  2023-06-07T00:20:16Z

# %% [markdown]
# #####The above 1249 comments are not dropped because there is a high chance that different users can comment in the same way.

# %% [markdown]
# #2. Exploratory Data Analysis

# %%
# Distribution of comment lengths
comments_df['comment_length'] = comments_df['comment_text'].apply(lambda x: len(str(x)))
sns.histplot(comments_df['comment_length'], bins=30)
plt.xlabel('Comment Length')
plt.ylabel('Frequency')
plt.title('Distribution of Comment Lengths')
plt.show()

# %% [markdown]
# #3. Data Preparation

# %%
# raw_text = df['comment_text']
# # raw_text[:4]

# %%
# Step1: Converting the text to lower_case
# clean_text_1 = []

# def to_lower_case(df):
#   for words in raw_text:
#     clean_text_1.append(str.lower(words))

# %%
# clean_text_1[:4]

# %%
#Step2: Tokenization
# clean_text_2 = [word_tokenize(i) for i in clean_text_1]

# %%
# from nltk.tokenize import sent_tokenize, word_tokenize
# nltk.download('punkt')

# %%
# Step3: Word tokenization
# import re

# clean_text_3 = []
# for words in clean_text_2:
#     clean = []
#     for w in words:
#         res = re.sub(r'[^\w\s]', "", w)
#         if res != "":
#             clean.append(res)
#     clean_text_3.append(clean)

# %%
#Step4: Stopword Removal
# nltk.download('stopwords')

# %%
# clean_text_4 = []

# for words in clean_text_3:
#   w = []
#   for word in words:
#     if not word in stopwords.words('english'):
#       w.append(word)
#     clean_text_4.append(w)

# %%
#Step 5: Lemmatization
# wnet = WordNetLemmatizer()

# %%
# nltk.download('wordnet')

# %%
# lem = []
# for words in clean_text_4:
#   w = []
#   for word in words:
#     w.append(wnet.lemmatize(word))
#   lem.append(w)

# %%
# lem[:4]

# %%
# raw_text[:4]

# %% [markdown]
# # 3. Data Cleaning

# %%
from bs4 import BeautifulSoup
import re

def clean_text(text):
    # Remove HTML tags
    text = BeautifulSoup(text, 'html.parser').get_text()
    # Remove special characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

# Clean the 'comment_text' column
comments_df['cleaned_text'] = comments_df['comment_text'].apply(clean_text)
# Out:
# <ipython-input-24-4b73e1281577>:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'html.parser').get_text()

# %%
comments_df.head(3)
# Out:
#                                         comment_text           author  likes  \
# 0                  The cable is definitely removable    @matrixmodexp      0
# 1  <a href="https://www.youtube.com/watch?v=dtp6b...       @saintpiff      0
# 2  This is a sad video of how they are Fixing to ...  @davidhelton497      0
#
#               timestamp  comment_length  \
# 0  2024-04-21T23:33:23Z              33
# 1  2024-04-21T18:37:16Z             169
# 2  2024-04-21T15:03:32Z             306
#
#                                         cleaned_text
# 0                  the cable is definitely removable
# 1    i know the people who developed the face sca...
# 2  this is a sad video of how they are fixing to ...

# %% [markdown]
# Check for comments not in English

# %%
pip install langdetect

# %%
# Checking for duplicated rows
duplicates = comments_df.duplicated()

# Display duplicated rows
comments_df[duplicates]
# Out:
#                                             comment_text               author  \
# 4144                   The renders from 2012 are reality     @user-cg7oq8cy9q
# 41894  Its not gaming focused...im trying to figure o...      @rosecity_chris
# 52269  Apple can never compete in VR, cause they are ...     @jasonhunter6125
# 53752               porn is the best application of this  @religionbuster7180
#
#        likes             timestamp  comment_length  \
# 4144       0  2024-02-05T16:04:42Z              33
# 41894      0  2023-06-06T18:51:44Z              94
# 52269      0  2023-06-06T09:38:06Z             129
# 53752      0  2023-06-06T08:33:24Z              36
#
#                                             cleaned_text
# 4144                       the renders from  are reality
# 41894  its not gaming focusedim trying to figure out ...
# 52269  apple can never compete in vr cause they are s...
# 53752               porn is the best application of this

# %% [markdown]
# Check for empty rows

# %%
# Check for empty rows
empty_rows = comments_df[comments_df['cleaned_text'].isnull() | (comments_df['cleaned_text'] == '')]

# Display empty rows
empty_rows.sample(10)
# Out:
#                                             comment_text  \
# 8120   <a href="https://www.youtube.com/watch?v=dtp6b...
# 58781                                                  1
# 58575                                                 😍😍
# 58144                                               🇮🇳❤️
# 3405                                            😅😅😂😂🤦🏽🤦🏽
# 7136                                             🍿🍿🍿😄😄😄😄
# 1921                                               🔥🔥🔥🔥🔥
# 48987                                                😶😶😶
# 10541                                              🤣🤣🤣🤣🤣
# 14084                                                  ❤
#
#                       author  likes             timestamp  comment_length  \
# 8120         @zohayer.mehtab      0  2024-02-03T14:11:12Z              72
# 58781         @harshkarn7874      0  2023-06-06T06:40:25Z               1
# 58575                @thenu.      0  2023-06-06T06:42:11Z               2
# 58144  @suraj-prakash-sharma      0  2023-06-06T06:52:19Z               4
# 3405              @Atlas1983      0  2024-02-06T08:02:40Z               8
# 7136                @IntDave      1  2024-02-03T20:24:21Z               7
# 1921    @springergabriel1804      0  2024-02-08T17:58:22Z               5
# 48987         @DavinaJordan.      0  2023-06-06T12:26:03Z               3
# 10541            @JimmySirya      0  2024-02-02T17:59:05Z               5
# 14084             @ff11dream      0  2024-02-01T11:32:18Z               1
#
#       cleaned_text
# 8120
# 58781
# 58575
# 58144
# 3405
# 7136
# 1921
# 48987
# 10541
# 14084

# %%
# Drop rows where 'cleaned_text' is empty
df_cleaned = comments_df[comments_df['cleaned_text'].notnull() & (comments_df['cleaned_text'] != '')]

# Check the shape of the DataFrame before and after dropping empty 'cleaned_text' rows
print("Original DataFrame shape:", comments_df.shape)
print("DataFrame shape after dropping empty 'cleaned_text' rows:", df_cleaned.shape)
# Out:
# Original DataFrame shape: (59253, 6)
# DataFrame shape after dropping empty 'cleaned_text' rows: (58912, 6)

# %%
df_cleaned.head()
# Out:
#                                         comment_text           author  likes  \
# 0                  The cable is definitely removable    @matrixmodexp      0
# 1  <a href="https://www.youtube.com/watch?v=dtp6b...       @saintpiff      0
# 2  This is a sad video of how they are Fixing to ...  @davidhelton497      0
# 3  BASE ON MY EXPERIENCE IT WILL BE PHASE-OUT IN ...        @aeoh2000      0
# 4  Typing is probably not great on this thing. Ho...     @immortalsun      0
#
#               timestamp  comment_length  \
# 0  2024-04-21T23:33:23Z              33
# 1  2024-04-21T18:37:16Z             169
# 2  2024-04-21T15:03:32Z             306
# 3  2024-04-21T08:28:44Z             124
# 4  2024-04-21T07:28:13Z             217
#
#                                         cleaned_text
# 0                  the cable is definitely removable
# 1    i know the people who developed the face sca...
# 2  this is a sad video of how they are fixing to ...
# 3  base on my experience it will be phaseout in t...
# 4  typing is probably not great on this thing hop...

# %% [markdown]
# #Tokenization and removal of stopwords

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Downloading the stopwords corpus and punkt tokenizer
# nltk.download('stopwords')
# nltk.download('punkt')

# Defining a function to tokenize text and remove stopwords
def tokenize_and_remove_stopwords(text):
    # Tokenizing the text into words
    tokens = word_tokenize(text)

    # Removing stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

    return filtered_tokens

# Applying the function to each row in the 'cleaned_text' column
df_cleaned['tokenized_text'] = df_cleaned['cleaned_text'].apply(tokenize_and_remove_stopwords)

# Displaying the first few rows of the DataFrame with tokenized text
df_cleaned[['cleaned_text', 'tokenized_text']].head()
# Out:
# <ipython-input-32-3ef877a822fa>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['tokenized_text'] = df_cleaned['cleaned_text'].apply(tokenize_and_remove_stopwords)
#                                         cleaned_text  \
# 0                  the cable is definitely removable
# 1    i know the people who developed the face sca...
# 2  this is a sad video of how they are fixing to ...
# 3  base on my experience it will be phaseout in t...
# 4  typing is probably not great on this thing hop...
#
#                                       tokenized_text
# 0                     [cable, definitely, removable]
# 1  [know, people, developed, face, scan, k, sick,...
# 2  [sad, video, fixing, implement, chips, brains,...
# 3  [base, experience, phaseout, next, one, two, y...
# 4  [typing, probably, great, thing, hopefully, on...

# %%
df_cleaned.head()
# Out:
#                                         comment_text           author  likes  \
# 0                  The cable is definitely removable    @matrixmodexp      0
# 1  <a href="https://www.youtube.com/watch?v=dtp6b...       @saintpiff      0
# 2  This is a sad video of how they are Fixing to ...  @davidhelton497      0
# 3  BASE ON MY EXPERIENCE IT WILL BE PHASE-OUT IN ...        @aeoh2000      0
# 4  Typing is probably not great on this thing. Ho...     @immortalsun      0
#
#               timestamp  comment_length  \
# 0  2024-04-21T23:33:23Z              33
# 1  2024-04-21T18:37:16Z             169
# 2  2024-04-21T15:03:32Z             306
# 3  2024-04-21T08:28:44Z             124
# 4  2024-04-21T07:28:13Z             217
#
#                                         cleaned_text  \
# 0                  the cable is definitely removable
# 1    i know the people who developed the face sca...
# 2  this is a sad video of how they are fixing to ...
# 3  base on my experience it will be phaseout in t...
# 4  typing is probably not great on this thing hop...
#
#                                       tokenized_text
# 0                     [cable, definitely, removable]
# 1  [know, people, developed, face, scan, k, sick,...
# 2  [sad, video, fixing, implement, chips, brains,...
# 3  [base, experience, phaseout, next, one, two, y...
# 4  [typing, probably, great, thing, hopefully, on...

# %% [markdown]
# #Lemmatization

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('averaged_perceptron_tagger')

# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Function to get POS tag for each token
def get_wordnet_pos(token):
    tag = nltk.pos_tag([token])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# Define a function to lemmatize a list of tokens
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]

# Apply lemmatization to the tokenized_text column
df_cleaned['lemmatized_text'] = df_cleaned['tokenized_text'].apply(lemmatize_tokens)

# Display the DataFrame with the lemmatized text
df_cleaned.head()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# <ipython-input-36-d1b8ae41041a>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['lemmatized_text'] = df_cleaned['tokenized_text'].apply(lemmatize_tokens)
#                                         comment_text           author  likes  \
# 0                  The cable is definitely removable    @matrixmodexp      0
# 1  <a href="https://www.youtube.com/watch?v=dtp6b...       @saintpiff      0
# 2  This is a sad video of how they are Fixing to ...  @davidhelton497      0
# 3  BASE ON MY EXPERIENCE IT WILL BE PHASE-OUT IN ...        @aeoh2000      0
# 4  Typing is probably not great on this thing. Ho...     @immortalsun      0
#
#               timestamp  comment_length  \
# 0  2024-04-21T23:33:23Z              33
# 1  2024-04-21T18:37:16Z             169
# 2  2024-04-21T15:03:32Z             306
# 3  2024-04-21T08:28:44Z             124
# 4  2024-04-21T07:28:13Z             217
#
#                                         cleaned_text  \
# 0                  the cable is definitely removable
# 1    i know the people who developed the face sca...
# 2  this is a sad video of how they are fixing to ...
# 3  base on my experience it will be phaseout in t...
# 4  typing is probably not great on this thing hop...
#
#                                       tokenized_text  \
# 0                     [cable, definitely, removable]
# 1  [know, people, developed, face, scan, k, sick,...
# 2  [sad, video, fixing, implement, chips, brains,...
# 3  [base, experience, phaseout, next, one, two, y...
# 4  [typing, probably, great, thing, hopefully, on...
#
#                                      lemmatized_text
# 0                     [cable, definitely, removable]
# 1  [know, people, developed, face, scan, k, sick,...
# 2  [sad, video, fix, implement, chip, brain, ive,...
# 3  [base, experience, phaseout, next, one, two, y...
# 4  [type, probably, great, thing, hopefully, one,...

# %% [markdown]
# #Modeling
#
# Using VADER Model

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()

# Join the lemmatized text back into a single string
df_cleaned['joined_text'] = df_cleaned['lemmatized_text'].apply(lambda x: ' '.join(x))

# Calculate sentiment scores for each joined text
df_cleaned['Positive'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['pos'])
df_cleaned['Negative'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['neg'])
df_cleaned['Neutral'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['neu'])
df_cleaned['Compound'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['compound'])

# Categorize sentiment based on Compound score
df_cleaned['Sentiment'] = df_cleaned['Compound'].apply(lambda x: 'Positive' if x >= 0.05 else ('Negative' if x <= -0.05 else 'Neutral'))

# Drop the temporary 'joined_text' column
df_cleaned.drop('joined_text', axis=1, inplace=True)

df_cleaned.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# <ipython-input-37-fbef4ba13046>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['joined_text'] = df_cleaned['lemmatized_text'].apply(lambda x: ' '.join(x))
# <ipython-input-37-fbef4ba13046>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Positive'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['pos'])
# <ipython-input-37-fbef4ba13046>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Negative'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['neg'])
# <ipython-input-37-fbef4ba13046>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Neutral'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['neu'])
# <ipython-input-37-fbef4ba13046>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Compound'] = df_cleaned['joined_text'].apply(lambda x: sentiments.polarity_scores(x)['compound'])
# <ipython-input-37-fbef4ba13046>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Sentiment'] = df_cleaned['Compound'].apply(lambda x: 'Positive' if x >= 0.05 else ('Negative' if x <= -0.05 else 'Neutral'))
# <ipython-input-37-fbef4ba13046>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop('joined_text', axis=1, inplace=True)
#                                         comment_text           author  likes  \
# 0                  The cable is definitely removable    @matrixmodexp      0
# 1  <a href="https://www.youtube.com/watch?v=dtp6b...       @saintpiff      0
# 2  This is a sad video of how they are Fixing to ...  @davidhelton497      0
# 3  BASE ON MY EXPERIENCE IT WILL BE PHASE-OUT IN ...        @aeoh2000      0
# 4  Typing is probably not great on this thing. Ho...     @immortalsun      0
#
#               timestamp  comment_length  \
# 0  2024-04-21T23:33:23Z              33
# 1  2024-04-21T18:37:16Z             169
# 2  2024-04-21T15:03:32Z             306
# 3  2024-04-21T08:28:44Z             124
# 4  2024-04-21T07:28:13Z             217
#
#                                         cleaned_text  \
# 0                  the cable is definitely removable
# 1    i know the people who developed the face sca...
# 2  this is a sad video of how they are fixing to ...
# 3  base on my experience it will be phaseout in t...
# 4  typing is probably not great on this thing hop...
#
#                                       tokenized_text  \
# 0                     [cable, definitely, removable]
# 1  [know, people, developed, face, scan, k, sick,...
# 2  [sad, video, fixing, implement, chips, brains,...
# 3  [base, experience, phaseout, next, one, two, y...
# 4  [typing, probably, great, thing, hopefully, on...
#
#                                      lemmatized_text  Positive  Negative  \
# 0                     [cable, definitely, removable]     0.574     0.000
# 1  [know, people, developed, face, scan, k, sick,...     0.000     0.320
# 2  [sad, video, fix, implement, chip, brain, ive,...     0.183     0.146
# 3  [base, experience, phaseout, next, one, two, y...     0.219     0.000
# 4  [type, probably, great, thing, hopefully, one,...     0.474     0.000
#
#    Neutral  Compound Sentiment
# 0    0.426    0.4019  Positive
# 1    0.680   -0.5106  Negative
# 2    0.671    0.1157  Positive
# 3    0.781    0.4215  Positive
# 4    0.526    0.9231  Positive

# %% [markdown]
# #Data Visualization - Pie Chart

# %%
import matplotlib.pyplot as plt

# Count the number of occurrences for each sentiment category
sentiment_counts = df_cleaned['Sentiment'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Sentiment Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Save the cleaned DataFrame to a CSV file
df_cleaned.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# #Model Evaluation (VADER)

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.2.2)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd
import numpy as np

# Define true sentiment labels from the 'Sentiment' column
true_sentiments = df_cleaned['Sentiment']

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to predict sentiment using VADER
def predict_sentiment(text):
    compound_score = analyzer.polarity_scores(text)['compound']
    return 'positive' if compound_score >= 0 else 'negative'

# Apply VADER to predict sentiment for each text in the 'lemmatized_text' column
predicted_sentiments = df_cleaned['lemmatized_text'].apply(predict_sentiment)

# Get unique sentiment classes from true_sentiments and predicted_sentiments
unique_sentiments = np.unique(np.concatenate((true_sentiments, predicted_sentiments)))

# %%
# Generate confusion matrix
print("Confusion Matrix:")
conf_matrix = confusion_matrix(true_sentiments, predicted_sentiments)
conf_matrix_df = pd.DataFrame(conf_matrix, index=unique_sentiments, columns=unique_sentiments)
conf_matrix_df
# Out:
# Confusion Matrix:
#           Negative  Neutral  Positive  negative  positive
# Negative         0        0         0       278     10990
# Neutral          0        0         0         1     18295
# Positive         0        0         0         0     29348
# negative         0        0         0         0         0
# positive         0        0         0         0         0

# %%
# Get unique sentiment classes from true_sentiments
unique_sentiments = np.unique(true_sentiments)

# Generate confusion matrix
print("Confusion Matrix:")
conf_matrix = confusion_matrix(true_sentiments, predicted_sentiments, labels=unique_sentiments)
conf_matrix_df = pd.DataFrame(conf_matrix, index=unique_sentiments, columns=unique_sentiments)
conf_matrix_df
# Out:
# Confusion Matrix:
#           Negative  Neutral  Positive
# Negative         0        0         0
# Neutral          0        0         0
# Positive         0        0         0

# %% [markdown]
# # Sentiment Analysis using SUPPORT VECTOR MACHINES (SVM)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Convert lists of lemmatized tokens into strings
X_train_str = [' '.join(tokens) for tokens in X_train]
X_test_str = [' '.join(tokens) for tokens in X_test]

# Initialize the TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=5000)

# Fitting and transforming the training data
X_train_tfidf = vectorizer.fit_transform(X_train_str)

# Transforming the testing data
X_test_tfidf = vectorizer.transform(X_test_str)

# Initializing the SVM classifier
svm_classifier = SVC(kernel='linear')

# Training the SVM classifier
svm_classifier.fit(X_train_tfidf, y_train)

# Predicting sentiment labels for the testing data
y_pred = svm_classifier.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Generate classification report
print("Classification Report:")
class_report = classification_report(y_test, y_pred)
print(class_report)

# Generate confusion matrix
print("Confusion Matrix:")
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# Accuracy: 0.9144530255452771
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.76      0.81      2289
#      Neutral       0.93      0.96      0.95      3705
#     Positive       0.92      0.95      0.93      5789
#
#     accuracy                           0.91     11783
#    macro avg       0.91      0.89      0.90     11783
# weighted avg       0.91      0.91      0.91     11783
#
# Confusion Matrix:
# [[1734  137  418]
#  [  57 3559   89]
#  [ 195  112 5482]]
